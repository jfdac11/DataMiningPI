# %% [markdown]
# <a href="https://colab.research.google.com/github/jfdac11/DataMiningPI/blob/develop/PreProcessamento_PortalTransparencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação das bibliotecas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive

# %%
#Concedendo acesso ao drive do projeto
drive.mount('/content/drive')
path = '/content/drive/Shareddrives/PI_2_2021'
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Importação do dataset bruto

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)

# %%
data = pd.read_csv(path + '/dobrano_.csv', header=0, sep=';', low_memory=False, encoding='latin1')
data.shape
# Out:
# (1581645, 86)

# %%
data.head()
# Out:
#    contador  ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 0         1       1         2  25012020      421.0    831.0    310160.0
# 1         2       1         2  25012020     1910.0    831.0    316930.0
# 2         3       1         2  14012020     1727.0    835.0    351360.0
# 3         4       1         2  20012020     1930.0    831.0    313870.0
# 4         5       1         2  26012020     2230.0    831.0    311090.0
#
#        DTNASC  IDADE  SEXO  RACACOR  ESTCIV  ESC  ESC2010  SERIESCFAL  \
# 0  10051951.0  468.0     1      1.0     4.0  2.0      1.0         3.0
# 1  16031966.0  453.0     1      2.0     1.0  2.0      1.0         1.0
# 2  10071937.0  482.0     2      1.0     2.0  2.0      1.0         1.0
# 3   2111946.0  473.0     2      1.0     4.0  2.0      1.0         3.0
# 4  12091959.0  460.0     1      1.0     1.0  5.0      5.0         NaN
#
#        OCUP  CODMUNRES  LOCOCOR   CODESTAB  CODMUNOCOR  IDADEMAE  ESCMAE  \
# 0  999993.0     316930        3        NaN      316930       NaN     NaN
# 1  621005.0     316930        3        NaN      316930       NaN     NaN
# 2  999992.0     316930        1  2760657.0      316930       NaN     NaN
# 3  999992.0     316080        1  2760657.0      316930       NaN     NaN
# 4  231205.0     311390        1  2760657.0      316930       NaN     NaN
#
#    ESCMAE2010  SERIESCMAE  OCUPMAE  QTDFILVIVO  QTDFILMORT  GRAVIDEZ  \
# 0         NaN         NaN      NaN         NaN         NaN       NaN
# 1         NaN         NaN      NaN         NaN         NaN       NaN
# 2         NaN         NaN      NaN         NaN         NaN       NaN
# 3         NaN         NaN      NaN         NaN         NaN       NaN
# 4         NaN         NaN      NaN         NaN         NaN       NaN
#
#    SEMAGESTAC  GESTACAO  PARTO  OBITOPARTO  PESO  TPMORTEOCO  OBITOGRAV  \
# 0         NaN       NaN    NaN         NaN   NaN         NaN        NaN
# 1         NaN       NaN    NaN         NaN   NaN         NaN        NaN
# 2         NaN       NaN    NaN         NaN   NaN         NaN        NaN
# 3         NaN       NaN    NaN         NaN   NaN         NaN        NaN
# 4         NaN       NaN    NaN         NaN   NaN         NaN        NaN
#
#    OBITOPUERP  ASSISTMED  EXAME  CIRURGIA  NECROPSIA LINHAA LINHAB LINHAC  \
# 0         NaN        2.0    NaN       NaN        2.0  *R99X    NaN    NaN
# 1         NaN        2.0    NaN       NaN        2.0  *R99X    NaN    NaN
# 2         NaN        NaN    NaN       NaN        NaN  *J960  *R571  *K922
# 3         NaN        1.0    NaN       NaN        2.0  *J960    NaN    NaN
# 4         NaN        1.0    NaN       NaN        2.0  *J960  *A419    NaN
#
#   LINHAD     LINHAII CAUSABAS  CB_PRE  COMUNSVOIM  DTATESTADO  CIRCOBITO  \
# 0    NaN         NaN      R99     NaN    316930.0  25012020.0        NaN
# 1    NaN         NaN      R99     NaN    316930.0  25012020.0        NaN
# 2    NaN  *K579*E46X     K579     NaN         NaN  14012020.0        NaN
# 3    NaN         NaN     J960     NaN    316930.0  20012020.0        NaN
# 4    NaN         NaN     A419     NaN    316930.0  26012020.0        NaN
#
#    ACIDTRAB  FONTE  NUMEROLOTE  DTINVESTIG  DTCADASTRO  ATESTANTE STCODIFICA  \
# 0       NaN    NaN  20200003.0         NaN   3022020.0        3.0          S
# 1       NaN    NaN  20200003.0         NaN   3022020.0        3.0          S
# 2       NaN    NaN  20200003.0         NaN   3022020.0        1.0          S
# 3       NaN    NaN  20200003.0         NaN   3022020.0        3.0          S
# 4       NaN    NaN  20200003.0         NaN   3022020.0        3.0          S
#
#   CODIFICADO VERSAOSIST  VERSAOSCB  FONTEINV   DTRECEBIM  \
# 0          S     3.2.02        3.2       NaN  12022020.0
# 1          S     3.2.02        3.2       NaN  12022020.0
# 2          S     3.2.02        3.2       NaN  12022020.0
# 3          S     3.2.02        3.2       NaN  12022020.0
# 4          S     3.2.02        3.2       NaN  12022020.0
#
#                   ATESTADO  DTRECORIGA  OPOR_DO CAUSAMAT  ESCMAEAGR1  \
# 0                      R99    12022020       18      NaN         NaN
# 1                      R99    12022020       18      NaN         NaN
# 2  J960/R571/K922*K579 E46    12022020       29      NaN         NaN
# 3                     J960    12022020       23      NaN         NaN
# 4                J960/A419    12022020       17      NaN         NaN
#
#    ESCFALAGR1  STDOEPIDEM  STDONOVA  DIFDATA  NUDIASOBCO  DTCADINV  \
# 0         1.0         0.0         1       18         NaN       NaN
# 1         1.0         0.0         1       18         NaN       NaN
# 2         1.0         0.0         1       29         NaN       NaN
# 3         1.0         0.0         1       23         NaN       NaN
# 4         8.0         0.0         1       17         NaN       NaN
#
#    TPOBITOCOR  DTCONINV FONTES  TPRESGINFO TPNIVELINV  DTCADINF  MORTEPARTO  \
# 0         NaN       NaN    NaN         NaN        NaN       NaN         NaN
# 1         NaN       NaN    NaN         NaN        NaN       NaN         NaN
# 2         NaN       NaN    NaN         NaN        NaN       NaN         NaN
# 3         NaN       NaN    NaN         NaN        NaN       NaN         NaN
# 4         NaN       NaN    NaN         NaN        NaN       NaN         NaN
#
#    DTCONCASO  ALTCAUSA CAUSABAS_O TPPOS  TP_ALTERA CB_ALT
# 0        NaN       NaN        R99     N        NaN    NaN
# 1        NaN       NaN        R99     N        NaN    NaN
# 2        NaN       NaN       K579     N        NaN    NaN
# 3        NaN       NaN       J960     N        NaN    NaN
# 4        NaN       NaN       A419     N        NaN    NaN

# %%
#Análise estatistica
data.describe()
# Out:
#            contador        ORIGEM      TIPOBITO       DTOBITO     HORAOBITO  \
# count  1.581645e+06  1.581645e+06  1.581645e+06  1.581645e+06  1.521078e+06
# mean   7.908230e+05  1.001587e+00  1.981725e+00  1.581028e+07  1.205621e+03
# std    4.565817e+05  3.980500e-02  1.339451e-01  8.817900e+06  6.731222e+02
# min    1.000000e+00  1.000000e+00  1.000000e+00  1
ORIGEM', 'TIPOBITO', 'DTOBITO', 'HORAOBITO', 'NATURAL',
#        'CODMUNNATU', 'DTNASC', 'IDADE', 'SEXO', 'RACACOR', 'ESTCIV', 'ESC',
#        'ESC2010', 'SERIESCFAL', 'OCUP', 'CODMUNRES', 'LOCOCOR', 'CODESTAB',
#        'CODMUNOCOR', 'IDADEMAE', 'ESCMAE', 'ESCMAE2010', 'SERIESCMAE',
#        'OCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'GRAVIDEZ', 'SEMAGESTAC',
#        'GESTACAO', 'PARTO', 'OBITOPARTO', 'PESO', 'TPMORTEOCO', 'OBITOGRAV',
#        'OBITOPUERP', 'ASSISTMED', 'EXAME', 'CIRURGIA', 'NECROPSIA', 'LINHAA',
#        'LINHAB', 'LINHAC', 'LINHAD', 'LINHAII', 'CAUSABAS', 'CB_PRE',
#        'COMUNSVOIM', 'DTATESTADO', 'CIRCOBITO', 'ACIDTRAB', 'FONTE',
#        'NUMEROLOTE', 'DTINVESTIG', 'DTCADASTRO', 'ATESTANTE', 'STCODIFICA',
#        'CODIFICADO', 'VERSAOSIST', 'VERSAOSCB', 'FONTEINV', 'DTRECEBIM',
#        'ATESTADO', 'DTRECORIGA', 'OPOR_DO', 'CAUSAMAT', 'ESCMAEAGR1',
#        'ESCFALAGR1', 'STDOEPIDEM', 'STDONOVA', 'DIFDATA', 'NUDIASOBCO',
#        'DTCADINV', 'TPOBITOCOR', 'DTCONINV', 'FONTES', 'TPRESGINFO',
#        'TPNIVELINV', 'DTCADINF', 'MORTEPARTO', 'DTCONCASO', 'ALTCAUSA',
#        'CAUSABAS_O', 'TPPOS', 'TP_ALTERA', 'CB_ALT'],
#       dtype='object')

# %% [markdown]
# # Pré-processamento dos dados

# %% [markdown]
# Algumas colunas precisaram ser deletadas, são elas:
#
# ```markdown
# * contador: pois já há o index das linhas do dataframe
# * CODINST: Código da instalação da geração dos registros
# * NUMERODV: número do dígito verificador (??)
# * HORAOBITO: hora de óbito
# * NUMSUS: número da carteira do sus
# * CODESTAB: código do estabelecimento
# * NUMERODN: número da declaração de nascimento
# * CRM: código de registro de médico, não precisaremos predizer
# * data do atestado de óbito
# * número do lote
# * data do cadastro: Indica se o mé
# dico que assina atendeu o paciente
# * Status de instalação: se codificadora
# se está codificado ou não
# * IDADEMAE:
# * ESCMAE
# * ESCMAE2010
# * OCUPMAE
# * PESO
# * ORIGEM
# * CB_PRE
# * SERIESCMAE
# * GRAVIDEZ
# * GESTACAO
# * SEMAGESTAC
# * PARTO
# * OBITOPARTO
# * OBITOGRAV
# * OBITOPUERP
# * ESCMAEAGR1
# * ESCFALAGR1
# * FONTES
# * QTDFILVIVO
# * QTDFILMORT
# * VERSAOSIST
# * VERSAOSCB
# * CODMUNRES
# * NUDIASOBCO
# * DTCADINV
# * DTCONINV
# * TPPOS
# * TPRESGINFO
# * TPMORTEOCO
# * NECROPSIA
# * COMUNSVOIM
# * DTINVESTIG
# * DTRECEBIM
# * CAUSAMAT
# * MORTEPARTO
# * ALTCAUSA
# * DTCONCASO
# * CIRURGIA
# * ACIDTRAB
# * FONTEINV
# * TIPOBITO
# * ESTCIV
# * ESC
# * SERIESCFAL
# * CODMUNNATU
# * TPOBITOCOR
# * TPNIVELINV
# * NATURAL
# * EXAME
# * FONTES
# * DTCADINF
# * NUDIASOBCO
# * STDONOVA
# * STDOEPIDEM
# * DTRECORIGA
# * DIFDATA
# * ATESTADO
# * LINHAA
# * LINHAB
# * LINHAC
# * LINHAD
# * LINHAII
# * CAUSABAS_O
# * FONTE
# * TP_ALTERA
# * CB_ALT
# * OPOR_DO
# * CIRCOBITO
# * 'FONTESINF
# * ESTABDESCR
# * NUDIASOBIN
# * NUDIASINF
#
# ```

# %%
limit = data.shape[0]
df = data[:limit]
# deletando colunas:

# %% [markdown]
# #Funções para tradução dos dados

# %% [markdown]
# ####Idades:

# %% [markdown]
# ##### ⏰
# * Para 2 dígitos: menos de 1 ano de vida
#
#
# * Para 3 dígitos com menor do que 400: menos de 1 ano de vida
#
#
# * Para 3 dígitos maiores do que 400:
#   * 2 últimos significam o número de anos
#   * o 1 primeiro significa  número de centenário a partir de 400

# %%
def ajeitando_idades(df):
    idades = pd.DataFrame(df['IDADE']).astype('int')
#     print(idades.head())
    idades['ANOS_IDADE'] = pd.Series()
    
    idades.loc[idades['IDADE'] < 400, ['ANOS_IDADE']] = 0
    
    idades.loc[idades['IDADE'] > 400, ['ANOS_IDADE']] = (idades['IDADE'] - 400)
    
    return idades['ANOS_IDADE']

# %%
def faixa_etaria(df):
    faixas_etarias = np.arange(0, df.IDADE.max()+1, 5, dtype='int')
    df['FAIXA_ETARIA'] = pd.cut(df['IDADE'], faixas_etarias)

# %%
def add_zero(row, name):
    if len(row[name]) < 8:
        row[name] = '0' + row[name]

# %% [markdown]
# #### Corrigindo as datas, pois algumas não possuem 8 carácteres

# %%
def clean_date(df, name_column):
    dt_nasc = pd.DataFrame(df[name_column])
    
    dt_nasc[name_column] = dt_nasc[name_column].fillna(0)
    dt_nasc[name_column] = dt_nasc[name_column].astype('int')
    dt_nasc[name_column] = dt_nasc[name_column].astype('str')
    

    dt_nasc.apply(add_zero, name=name_column, axis='columns')
    dt_nasc[name_column] = dt_nasc[name_column].str.slice(0, 8)
    
    
    dt_nasc['ANO'] = dt_nasc[name_column].str[4:]

    dt_nasc['MES'] = dt_nasc[name_column].str.slice(2, 4)

    dt_nasc['DIA'] = dt_nasc[name_column].str.slice(0, 2)
    

    return dt_nasc

# %% [markdown]
# #### Pegando o parte do código do município equivalente ao estado para atribuir sua respectiva sigla (UF)

# %%
def codigos(row):
    if len(row['CODMUNOCOR']) < 7:
#         print('0' + row.DTOBITO[0])
        row['COD'] = row.CODMUNOCOR[:2]

# %% [markdown]
# ##### Atribuindo siglas das UFs de acordo com seus códigos segundo o CSV dos estados do IBGE

# %%
def clean_states(df):
    data_estados = pd.read_csv(path + '/CSVs BASE/estados_ibge.csv', sep=';', header=0, encoding='latin1')

    cod = pd.Series(data_estados['CODIGO'].astype('str'))
    cod = cod.values

    uf = pd.Series(data_estados['UF'].astype('str'))
    uf = uf.values

    cod_mun = pd.DataFrame(df.CODMUNOCOR.astype('str'))

    cod_mun['CODMUNOCOR'] = cod_mun.CODMUNOCOR.astype('str')
    cod_mun['CODMUNOCOR'].str.slice(0,2)
    cod_mun['COD'] = ""
    cod_mun.apply(codigos, axis='columns')
    cod_mun['ESTADO'] = cod_mun['COD'].replace(cod, uf)

    return cod_mun['ESTADO'], cod_mun['COD']

# %% [markdown]
# ####Retirando * das tuplas em que a causa básica contém antes do valor CID

# %%
def limpeza(row, col_cids):
    for c in col_cids:
        if row[c].find('*') != -1:
            row[c] = row[c][1:]

# %% [markdown]
# #####Agrupando causa básica de acordo com a tabela CAPÍTULOS do CID-10

# %%
def capitulo_cid(row, cids):
    cids.loc[( ( (cids.CAUSABAS.str[0] == row.CATINIC[0]) | (cids.CAUSABAS.str[0] == row.LETRA_FIM) )
              &
               ((cids.CAUSABAS.str[1:3] >= row.CATINIC[1:]) & (cids.CAUSABAS.str[1:3] <= row.CATFIM[1:]))
             ),
             ['CAPITULO_CAUSA_BASICA', 'COD_CAPITULO_CAUSA_BASICA']] = [row.DESCRABREV, row.NUMCAP]

# %% [markdown]
# #### Agrupando causa básica de acordo com a tabela de GRUPOS do CID-10

# %%
#grupo CID
def agrupamento_cid(row, cids):
    valores = pd.DataFrame()
    valores['CAUSABAS'] = cids.CAUSABAS.str[1:3].astype('int')
    inicio = int(row.CATINIC[1:])
    fim = int(row.CATFIM[1:])
    
    cids.loc[( ( (cids.CAUSABAS.str[0] == row.CATINIC[0]) | (cids.CAUSABAS.str[0] == row.LETRA_FIM) )
              &
               ((cids.CAUSABAS.str[1:3] >= row.CATINIC[1:]) & (cids.CAUSABAS.str[1:3] <= row.CATFIM[1:]))
             )
            , ['COD_GRUPO_CAUSA_BASICA', 'GRUPO_CAUSA_BASICA']] = [row.CATINIC + '-' + row.CATFIM, row.DESCRICAO]

# %% [markdown]
# #### Atribuindo categoria e subcategorias do CID-10 que a CAUSA BÁSICA equivale

# %%
#CATEGORIA CID
#(cids.CAUSABAS.str.len() == 3) &
def categoria_cid(row, cids):
    cids.loc[((cids.CAUSABAS.str[:3] == row.CAT)),
             ['COD_CAUSA_BASICA', 'CAUSA_BASICA']] = [row.CAT, row.DESCRICAO]

# %%
#SUBCATEGORIA CID 
def sub_categoria_cid(row, cids):
    cids.loc[((cids.CAUSABAS.str.len() == 4) & (cids.CAUSABAS == row.SUBCAT)),
            ['CAUSA_BASICA']] = row.DESCRABREV[6:]

# %% [markdown]
# #### Função para tratar os valores da coluna CAUSABAS:
#   vai classificar o grupo CID-10, categoria e subcategoria CID-10 e o capítulo CID-10

# %%
def nomeando_cids(df):
    df_cid_grupos = pd.read_csv(path + '/CSVs BASE/CID-10-GRUPOS.CSV', header=0, sep=';', encoding='latin1')
    df_cid_grupos.head()

    # df_cid_grupos = df_cid_grupos.drop(columns=['Unnamed: 0'])


    df_cid_cate = pd.read_csv(path + '/CSVs BASE/CID-10-CATEGORIAS.CSV', header=0, sep=';', encoding='latin1')

    df_cid_sub = pd.read_csv(path + '/CSVs BASE/CID-10-SUBCATEGORIAS.CSV', header=0, sep=';', encoding='latin1')
    
    df_cid_cap = pd.read_csv(path + '/CSVs BASE/CID-10-CAPITULOS.CSV', header=0, sep=';', encoding='latin1')

    df_cid_cap['LETRA_INICIO'] = ""
    df_cid_cap['NUM_INICIO'] = ""
    df_cid_cap['LETRA_FIM'] = ""
    df_cid_cap['NUM_FIM'] = ""
    
    df_cid_grupos['LETRA_INICIO'] = ""
    df_cid_grupos['NUM_INICIO'] = ""
    df_cid_grupos['LETRA_FIM'] = ""
    df_cid_grupos['NUM_FIM'] = ""
    
    col_cids = ['CAUSABAS']

    cids = pd.DataFrame(df[col_cids].astype('str'))

#### RETIRANDO O '*' INÍCIO
    cids.apply(limpeza, col_cids=col_cids, axis='columns')

    cids['GRUPO_CAUSA_BASICA'] = ""
    cids['COD_GRUPO_CAUSA_BASICA'] = ""
    cids['COD_CAUSA_BASICA'] = ""
    cids['CAUSA_BASICA'] = ""
    cids['CAPITULO_CAUSA_BASICA'] = ""
    cids['COD_CAPITULO_CAUSA_BASICA'] = ""
    
    df_cid_cap.apply(capitulo_cid, cids=cids, axis='columns')

    df_cid_grupos.apply(agrupamento_cid, cids=cids, axis='columns')

    df_cid_cate.apply(categoria_cid, cids=cids, axis='columns')
    df_cid_sub.apply(sub_categoria_cid, cids=cids, axis='columns')
    
    return cids

# %% [markdown]
# #### Tratando a ocupação da pessoa
# Criação de duas novas colunas: uma com o código do grupo pertencente e outra com a descrição deste

# %% [markdown]
# #####Atribuindo descrição do grupo de ocupação de acordo com o código

# %%
def cod_ocup(row, ocupacoes):
    ocupacoes.loc[(ocupacoes.OCUP.str[:6] == row.CODIGO), ['OCUPACAO']] = row.TITULO

# %% [markdown]
# Atribuindo código do grupo de ocupação de acordo com o código

# %%
def cod_group_ocup(row, ocupacoes):
    ocupacoes.loc[(ocupacoes.OCUP.str[0] == row.CODIGO), 
                  ['GRUPO_OCUPACAO', 'CODIGO_GRUPO_OCUPACAO']] = [row.TITULO, row.CODIGO]

# %% [markdown]
# #### Realizando tratamento das ocupações de acordo com o CSV da Classificação Brasileira de Ocupações

# %%
def ocupacoes(df):
#     df_ocupacoes = pd.read_csv('../../Downloads/CBO2002_Ocupacao.csv', header=0, sep=';', encoding='latin1')
    df_grupo = pd.read_csv(path + '/CSVs BASE/CBO2002_Grande_Grupo.csv', header=0, sep=';', encoding='latin1')
    
#     df_ocupacoes['CODIGO'] = df_ocupacoes['CODIGO'].astype('str')
    df_grupo['CODIGO'] = df_grupo['CODIGO'].astype('str')
    
    ocupacoes = pd.DataFrame(df['OCUP'].astype('str'))
#     ocupacoes['OCUPACAO'] = "" 
    ocupacoes['GRUPO_OCUPACAO'] = ""
    ocupacoes['CODIGO_GRUPO_OCUPACAO'] = ""
    
#     df_ocupacoes.apply(cod_ocup, ocupacoes=ocupacoes, axis='columns')
    df_grupo.apply(cod_group_ocup, ocupacoes=ocupacoes, axis='columns')
    ocupacoes['GRUPO_OCUPACAO'] = ocupacoes['GRUPO_OCUPACAO'].fillna('SEM OCUPAÇÃO') 
    
    return ocupacoes['GRUPO_OCUPACAO'], ocupacoes['CODIGO_GRUPO_OCUPACAO']

# %% [markdown]
# #### Criação do CSV com apenas dados em que a causa básica foi "coronavirus" e retirada dessas tuplas do pré-processamento

# %%
def retirando_covid(df):
    
    df_covid = df.loc[df['CAUSA_BASICA'].str.contains('coronavirus') == True]
    # df_covid = df_covid.drop(columns=['CAUSA_BASICA'])
    df_covid.columns = df_covid.columns.str.lower()
    df_covid = df_covid.rename(columns={'assistmed': 'teve_assistencia_medica', 'racacor': 'raca_cor', 'lococor': 'local_ocorrencia',
                   'esc2010': 'escolaridade'})
    
    df_covid.to_csv(path + '/Datasets Pre-processados/mortes_por_covid_2020.csv', header=True, sep=';', encoding='latin1', index=False)
    
    df_sem_covid = df.loc[df['CAUSA_BASICA'].str.contains('coronavirus') == False]
    
    return df_sem_covid

# %% [markdown]
# #### Função principal de limpeza do DATASET
# Nela que haverão as chamadas das funções anteriores

# %%
def clean_dataset(df):
  
    # retirando as circunstância de óbito que não envolvem doença como causa
    df = df.loc[(df['CIRCOBITO'].isnull()) | (df['CIRCOBITO'] == 9)] 
    
#### DROP COLUMNS
    df = df.drop(columns=['contador','DTNASC', 'HORAOBITO', 'CODESTAB', 'DTATESTADO', 'NUMEROLOTE', 'DTCADASTRO', 'ATESTANTE', 
                          'STCODIFICA', 'CODIFICADO']
                )

#### CATEGORIZANDO OS SEXOS

    df['SEXO'] = df['SEXO'].replace([0, 1, 2] , ["I", "M", "F"])

#### CATEGORIZANDO RAÇAS/COR

    df['RACACOR'] = df['RACACOR'].replace([1, 2, 3, 4, 5], 
                                          ['BRANCA', 'PRETA', 'AMARELA', 'PARDA', 'INDIGENA']
                                          )

#### DATA DE NASCIMENTO

#     dt_nasc = clean_date(df, 'DTNASC')


#     df['DIA_NASC'] = dt_nasc['DIA']
#     df['MES_NASC'] = dt_nasc['MES']
#     df['ANO_NASC'] = dt_nasc['ANO']
    
#     df['DIA_NASC'] = df['DIA_NASC'].astype('int')
#     df['MES_NASC'] = df['MES_NASC'].astype('int')
#     df['ANO_NASC'] = df['ANO_NASC'].astype('int')

#### DATA DE ÓBITO

    dt_obito = clean_date(df, 'DTOBITO')

#     df['DIA_OBITO'] = dt_obito['DIA'].astype('int')
    df['MES_OBITO'] = dt_obito['MES'].astype('int')
#     df['ANO_OBITO'] = dt_obito['ANO'].astype('int')


    df = df.drop(columns=['IDADEMAE', 'ESCMAE', 'ESCMAE2010', 'OCUPMAE', 'PESO', 'ORIGEM', 'CB_PRE', 
                          'SERIESCMAE', 'GRAVIDEZ', 'GESTACAO', 'SEMAGESTAC', 'PARTO', 'OBITOPARTO', 'OBITOGRAV', 'OBITOPUERP',
                          'ESCMAEAGR1', 'ESCFALAGR1', 'FONTES', 'QTDFILVIVO', 'QTDFILMORT', 'VERSAOSIST', 'VERSAOSCB', 
                          'CODMUNRES', 'NUDIASOBCO', 'DTCADINV', 'DTCONINV', 'TPPOS', 'TPRESGINFO', 'TPMORTEOCO', 'NECROPSIA',
                           'COMUNSVOIM', 'DTINVESTIG', 'DTRECEBIM', 'CAUSAMAT', 'MORTEPARTO', 'ALTCAUSA',
                          'DTCONCASO', 'CIRURGIA', 'ACIDTRAB', 'FONTEINV', 'TIPOBITO', 'ESTCIV', 'ESC', 'SERIESCFAL', 
                          'CODMUNNATU', 'TPOBITOCOR', 'TPNIVELINV', 'NATURAL', 'EXAME', 'FONTES', 'DTCADINF', 'NUDIASOBCO', 
                          'STDONOVA', 'STDOEPIDEM', 'DTRECORIGA', 'DIFDATA','ATESTADO',
                          'LINHAA', 'LINHAB', 'LINHAC', 'LINHAD', 'LINHAII', 'CAUSABAS_O', 'FONTE',
                          'TP_ALTERA', 'CB_ALT', 'OPOR_DO', 
                          #'CIRCOBITO',
                          # 'FONTESINF', 'ESTABDESCR', 'NUDIASOBIN', 'NUDIASINF',
                         ]
                )
    
#### AJEITANDO IDADES
    df = df.loc[df['IDADE'] <= 600]

    df['IDADE'] = df['IDADE'].fillna(0)

    df['IDADE'] = ajeitando_idades(df)
    
    faixa_etaria(df)
    
    df['IDADE'] = df['IDADE'].astype('int')


#### CATEGORIZANDO OS DADOS

    df['ASSISTMED'] = df['ASSISTMED'].replace([1, 2, 9], 
                                              ['SIM', 'NAO', 'I']
                                             )

    df['LOCOCOR'] = df['LOCOCOR'].replace([1, 2, 3, 4, 5, 9], 
                                          ['HOSPITAL', 'OES', 'DOMICILIO', 'VIAP', 'OUTROS', 'I']
                                         )
    # OES: outros estabelecimentos de saúde
    # I: ignorado
    # VIAP: via pública

    df['ESC2010'] = df['ESC2010'].replace([0, 1, 2, 3, 4, 5, 9], 
                                          ['SEM', 'EF_I', 'EF_II', 'EM', 'SUPERIOR_I', 'SUPERIOR_C', 'I']
                                         )
    # SEM: SEM ESCOLARIDADE
    # EF_I: ensino fundamental I
    # EF_II: ensino fundamental II
    # EM: ensino médio
    # SUPERIOR_I: superior incompleto
    # SUPERIOR_C: superior completo
    # I: ignorado

#### AJEITANDO OS ESTADOS
    df['ESTADO'], df['CODIGO_ESTADO'] = clean_states(df)

#### AJEITANDO CIDs

    cids = nomeando_cids(df)

    df['GRUPO_CAUSA_BASICA'] = cids['GRUPO_CAUSA_BASICA']
    df['COD_GRUPO_CAUSA_BASICA'] = cids['COD_GRUPO_CAUSA_BASICA']
    df['COD_CAUSA_BASICA'] = cids['COD_CAUSA_BASICA']
    df['CAUSA_BASICA'] = cids['CAUSA_BASICA']
    df['CAPITULO_CAUSA_BASICA'] = cids['CAPITULO_CAUSA_BASICA']
    df['COD_CAPITULO_CAUSA_BASICA'] = cids['COD_CAPITULO_CAUSA_BASICA']

    df = df.drop(columns=['CAUSABAS'])
    
    df = df.loc[((df.CAPITULO_CAUSA_BASICA != 19) & (df.CAPITULO_CAUSA_BASICA != 20))]

#### OCUPACAO DO ÓBITO

    df['OCUP'] = df['OCUP'].astype('str')
    df['GRUPO_OCUPACAO'], df['CODIGO_GRUPO_OCUPACAO']  = ocupacoes(df)
   
    df = df.drop(columns=['OCUP', 'CODMUNOCOR', 'DTOBITO'])
  
    df = retirando_covid(df)
    
    return df

# %% [markdown]
# ####chamando funções

# %%
  df = clean_dataset(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   after removing the cwd from sys.path.

# %%
df.columns = df.columns.str.lower()

# %%
df.dtypes
# Out:
# idade                           int64
# sexo                           object
# racacor                        object
# esc2010                        object
# lococor                        object
# assistmed                      object
# circobito                     float64
# mes_obito                       int64
# faixa_etaria                 category
# estado                         object
# codigo_estado                  object
# grupo_causa_basica             object
# cod_grupo_causa_basica         object
# cod_causa_basica               object
# causa_basica                   object
# capitulo_causa_basica          object
# cod_capitulo_causa_basica      object
# grupo_ocupacao                 object
# codigo_grupo_ocupacao          object
# dtype: object

# %%
df = df.rename(columns={'assistmed': 'teve_assistencia_medica', 'racacor': 'raca_cor', 'lococor': 'local_ocorrencia',
                   'esc2010': 'escolaridade'})

# %%
df.isnull().sum()
# Out:
# idade                              0
# sexo                               0
# raca_cor                       32013
# escolaridade                   96971
# local_ocorrencia                   0
# teve_assistencia_medica       405890
# circobito                    1197969
# mes_obito                          0
# faixa_etaria                   30514
# estado                             0
# codigo_estado                      0
# grupo_causa_basica                 0
# cod_grupo_causa_basica             0
# cod_causa_basica                   0
# causa_basica                       0
# capitulo_causa_basica              0
# cod_capitulo_causa_basica          0
# grupo_ocupacao                     0
# codigo_grupo_ocupacao              0
# dtype: int64

# %%
df.head()
# Out:
#    idade sexo raca_cor escolaridade local_ocorrencia teve_assistencia_medica  \
# 0     68    M   BRANCA         EF_I        DOMICILIO                     NAO
# 1     53    M    PRETA         EF_I        DOMICILIO                     NAO
# 2     82    F   BRANCA         EF_I         HOSPITAL                     NaN
# 3     73    F   BRANCA         EF_I         HOSPITAL                     SIM
# 4     60    M   BRANCA   SUPERIOR_C         HOSPITAL                     SIM
#
#    circobito  mes_obito faixa_etaria estado codigo_estado  \
# 0        NaN          1     (65, 70]     MG            31
# 1        NaN          1     (50, 55]     MG            31
# 2        NaN          1     (80, 85]     MG            31
# 3        NaN          1     (70, 75]     MG            31
# 4        NaN          1     (55, 60]     MG            31
#
#                                   grupo_causa_basica cod_grupo_causa_basica  \
# 0  Causas mal definidas e desconhecidas de mortal...                R95-R99
# 1  Causas mal definidas e desconhecidas de mortal...                R95-R99
# 2                      Outras doenças dos intestinos                K55-K63
# 3            Outras doenças do aparelho respiratório                J95-J99
# 4                         Outras doenças bacterianas                A30-A49
#
#   cod_causa_basica                                       causa_basica  \
# 0              R99  Outras causas mal definidas e as não especific...
# 1              R99  Outras causas mal definidas e as não especific...
# 2              K57         Doenc divert intest localiz NE s/perf absc
# 3              J96                               Insuf respirat aguda
# 4              A41                                      Septicemia NE
#
#                          capitulo_causa_basica cod_capitulo_causa_basica  \
# 0  Sint sinais e achad anorm ex clín e laborat                        18
# 1  Sint sinais e achad anorm ex clín e laborat                        18
# 2                Doenças do aparelho digestivo                        11
# 3             Doenças do aparelho respiratório                        10
# 4   Algumas doenças infecciosas e parasitárias                         1
#
#                                       grupo_ocupacao codigo_grupo_ocupacao
# 0  TRABALHADORES EM SERVIÇOS DE REPARAÇÃO E MANUT...                     9
# 1  TRABALHADORES AGROPECUÁRIOS, FLORESTAIS E DA P...                     6
# 2  TRABALHADORES EM SERVIÇOS DE REPARAÇÃO E MANUT...                     9
# 3  TRABALHADORES EM SERVIÇOS DE REPARAÇÃO E MANUT...                     9
# 4  PROFISSIONAIS DAS CIÊNCIAS E DAS ARTES        ...                     2

# %%
# df[df['causa_basica'].str.contains('coronavirus') == True]

# %% [markdown]
# #####SALVANDO DATASET APÓS PRÉPROCESSAMENTO

# %%
df.to_csv(path + '/Datasets Pre-processados/dobrano_2020_pre_preprocessado.csv', header=True, sep=';', encoding='latin1', index=False)

# %%
df.shape
# Out:
# (1226210, 19)
